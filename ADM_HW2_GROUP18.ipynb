# %% [markdown]
# ## ADM GROUP 18 HOMEWORK

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # RQ1

# %%
data=pd.read_csv("C:/Users/altyn/Downloads/hello/steam_reviews.csv",nrows=100000)

# %% [markdown]
# ## -1 understanding the data

# %% [markdown]
# ### Here 21747371 observations and 23 features in this dataset (in real there is more rows but i could only download this part)

# %%
data.shape
# Out:
# (100000, 23)

# %% [markdown]
# ### The head() function is used to get the first 5 rows. It is useful for quickly testing

# %%
data.head()
# Out:
#    Unnamed: 0  app_id                  app_name  review_id  language  \
# 0           0  292030  The Witcher 3: Wild Hunt   85185598  schinese
# 1           1  292030  The Witcher 3: Wild Hunt   85185250  schinese
# 2           2  292030  The Witcher 3: Wild Hunt   85185111  schinese
# 3           3  292030  The Witcher 3: Wild Hunt   85184605   english
# 4           4  292030  The Witcher 3: Wild Hunt   85184287  schinese
#
#                                               review  timestamp_created  \
# 0                            不玩此生遗憾，RPG游戏里的天花板，太吸引人了         1611381629
# 1                                 拔DIAO无情打桩机--杰洛特!!!         1611381030
# 2                                              巫师3NB         1611380800
# 3  One of the best RPG's of all time, worthy of a...         1611379970
# 4                                                 大作         1611379427
#
#    timestamp_updated  recommended  votes_helpful  ...  steam_purchase  \
# ...

# %% [markdown]
# ### The tail() function is used to return the last n rows.
#
# ### This function returns last n rows from the object based on position. It is useful for quickly verifying data

# %%
data.tail()
# Out:
#        Unnamed: 0  app_id                  app_name  review_id   language  \
# 99995       99995  292030  The Witcher 3: Wild Hunt   69870073    english
# 99996       99996  292030  The Witcher 3: Wild Hunt   69869984    english
# 99997       99997  292030  The Witcher 3: Wild Hunt   69869740   schinese
# 99998       99998  292030  The Witcher 3: Wild Hunt   69869693    english
# 99999       99999  292030  The Witcher 3: Wild Hunt   69869583  brazilian
#
#                                                   review  timestamp_created  \
# 99995  "Witchers were made to kill monsters. It doesn...         1590549322
# 99996                                  Awesome game 100%         1590549142
# 99997                                                 优秀         1590548696
# 99998                               Best game ever made.         1590548619
# 99999                          Uma obra prima dos jogos.         1590548390
#
# ...

# %% [markdown]
# ### Here im cheking all the columns in dataset. So we 23 columns of stream dataset

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'app_id', 'app_name', 'review_id', 'language', 'review',
#        'timestamp_created', 'timestamp_updated', 'recommended',
#        'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
#        'steam_purchase', 'received_for_free', 'written_during_early_access',
#        'author.steamid', 'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played'],
#       dtype='object')

# %% [markdown]
# ## And then we found the explanation of each column:
# ##### app_id contains the app id to which the review refers.
# ##### app_name contains the name of the app to which the review refers.
# ##### review_id contains the review id.
# ##### language contains the language in which the review was written.
# ##### review contains the text of the review.
# ##### timestamp_created the date of creation of the review.
# ##### timestamp_updated the date of last modification of the review.
# ##### recommended indicates if the author recommends the app.
# ##### votes_helpful indicates how how many authors find the review helpful.
# ##### votes_funny indicates how how many authors find the review funny.
# ##### weighted_vote_score contains the utility score.
# ##### comment_count contains the number of comments for each review.
# ##### steam_purchase indicates if the user purchased the game on steam.
# ##### received_for_free indicates if the app is free for the user.
# ##### written_during_early_access indicates if the author posted the review while the game was in early access.
# ##### author.steamid contains the id of the author.
# ##### author.num_games_owned indicates the number of games owned by the user.
# ##### author.num_reviews indicates the number of reviews written by an author.
# ##### author.playtime_forever indicates the total recorded game time for this application.
# ##### author.playtime_last_two_weeks indicates the game time recorded in the last two weeks for this application.
# ##### author.playtime_at_review indicates the game time in which the review was written.
# ##### author.last_played indicates the last time the user started the application.

# %% [markdown]
# ### here we are cheking the uniqness of our data

# %%
data.nunique()
# Out:
# Unnamed: 0                        100000
# app_id                                 1
# app_name                               1
# review_id                         100000
# language                              28
# review                             80179
# timestamp_created                  99564
# timestamp_updated                  99516
# recommended                            2
# votes_helpful                        220
# votes_funny                          111
# weighted_vote_score                 3466
# comment_count                         37
# steam_purchase                         2
# received_for_free                      2
# written_during_early_access            1
# author.steamid                    100000
# author.num_games_owned              1143
# author.num_reviews                   238
# author.playtime_forever            20146
# author.playtime_last_two_weeks      3919
# author.playtime_at_review          17596
# author.last_played                 99246
# ...

# %% [markdown]
# ### So lets see datatypes of each variable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      100000 non-null  int64
#  1   app_id                          100000 non-null  int64
#  2   app_name                        100000 non-null  object
#  3   review_id                       100000 non-null  int64
#  4   language                        100000 non-null  object
#  5   review                          99707 non-null   object
#  6   timestamp_created               100000 non-null  int64
#  7   timestamp_updated               100000 non-null  int64
#  8   recommended                     100000 non-null  bool
#  9   votes_helpful                   100000 non-null  int64
#  10  votes_funny                     100000 non-null  int64
#  11  weighted_vote_score             100000 non-null  float64
# ...

# %% [markdown]
# ### Here we can see that we have 4 bool columns and 16 numerical and 3 object columns

# %% [markdown]
# ### we can decribe our numerical operators

# %%
data.describe(include = ("float64",'int64'))
# Out:
#           Unnamed: 0    app_id     review_id  timestamp_created  \
# count  100000.000000  100000.0  1.000000e+05       1.000000e+05
# mean    49999.500000  292030.0  7.745769e+07       1.601702e+09
# std     28867.657797       0.0  4.569945e+06       6.282546e+06
# min         0.000000  292030.0  6.986958e+07       1.590548e+09
# 25%     24999.750000  292030.0  7.324672e+07       1.595660e+09
# 50%     49999.500000  292030.0  7.754843e+07       1.602685e+09
# 75%     74999.250000  292030.0  8.144077e+07       1.606883e+09
# max     99999.000000  292030.0  8.518560e+07       1.611382e+09
#
#        timestamp_updated  votes_helpful    votes_funny  weighted_vote_score  \
# count       1.000000e+05  100000.000000  100000.000000        100000.000000
# mean        1.601933e+09       0.917220       0.261350             0.087079
# std         6.267846e+06      19.467835       8.392454             0.195308
# min         1.590548e+09       0.000000       0.000000             0.000000
# ...

# %% [markdown]
# ### now lets see the unique datas in our table

# %%
data.nunique()
# Out:
# Unnamed: 0                        100000
# app_id                                 1
# app_name                               1
# review_id                         100000
# language                              28
# review                             80179
# timestamp_created                  99564
# timestamp_updated                  99516
# recommended                            2
# votes_helpful                        220
# votes_funny                          111
# weighted_vote_score                 3466
# comment_count                         37
# steam_purchase                         2
# received_for_free                      2
# written_during_early_access            1
# author.steamid                    100000
# author.num_games_owned              1143
# author.num_reviews                   238
# author.playtime_forever            20146
# author.playtime_last_two_weeks      3919
# author.playtime_at_review          17596
# author.last_played                 99246
# ...

# %% [markdown]
# ### As we can see here we have only one app_name and 28 languages and id's are not repeating

# %%
data['language'].unique()
# Out:
# array(['schinese', 'english', 'turkish', 'spanish', 'russian', 'koreana',
#        'latam', 'brazilian', 'portuguese', 'vietnamese', 'polish',
#        'french', 'german', 'hungarian', 'ukrainian', 'tchinese',
#        'bulgarian', 'czech', 'italian', 'thai', 'greek', 'dutch',
#        'finnish', 'romanian', 'japanese', 'swedish', 'danish',
#        'norwegian'], dtype=object)

# %%
data[["language"]].describe()
# Out:
#        language
# count    100000
# unique       28
# top     english
# freq      24956

# %% [markdown]
# ### from all 28 languages most popular one is english

# %% [markdown]
# ## now i'm gonna check the null values

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                          0
# app_id                              0
# app_name                            0
# review_id                           0
# language                            0
# review                            293
# timestamp_created                   0
# timestamp_updated                   0
# recommended                         0
# votes_helpful                       0
# votes_funny                         0
# weighted_vote_score                 0
# comment_count                       0
# steam_purchase                      0
# received_for_free                   0
# written_during_early_access         0
# author.steamid                      0
# author.num_games_owned              0
# author.num_reviews                  0
# author.playtime_forever             0
# author.playtime_last_two_weeks      0
# author.playtime_at_review           0
# author.last_played                  0
# dtype: int64

# %%
plt.barh(data.columns.values, data.isna().sum().values)
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# ### fter checking all the data i wanted to look into correlation between authors data only

# %%
author=data.drop(columns=['Unnamed: 0', 'app_id', 'app_name', 'review_id', 'language', 'review',
       'timestamp_created', 'timestamp_updated', 'recommended',
       'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
       'steam_purchase', 'received_for_free', 'written_during_early_access'])

# %%
data2=data.drop(columns=['Unnamed: 0', 'app_id','review_id'])

# %%
author.head()
# Out:
#       author.steamid  author.num_games_owned  author.num_reviews  \
# 0  76561199095369542                       6                   2
# 1  76561198949504115                      30                  10
# 2  76561199090098988                       5                   1
# 3  76561199054755373                       5                   3
# 4  76561199028326951                       7                   4
#
#    author.playtime_forever  author.playtime_last_two_weeks  \
# 0                   1909.0                          1448.0
# 1                   2764.0                          2743.0
# 2                   1061.0                          1061.0
# 3                   5587.0                          3200.0
# 4                    217.0                            42.0
#
#    author.playtime_at_review  author.last_played
# 0                     1909.0        1.611343e+09
# 1                     2674.0        1.611386e+09
# 2                     1060.0        1.611384e+09
# ...

# %%
corelation=author.corr()

# %%
corelation2=data2.corr()

# %% [markdown]
# ### Dark shades represents positive correlation while lighter shades represents negative correlation.

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.relplot(x='weighted_vote_score',y='votes_funny',hue='language',data=data)

# %% [markdown]
# #### HERE WE CAN SAY THAT SCHINESE AND ENGLISH GYUS  GIVES GOOD VOTE THAN OTHERS

# %% [markdown]
# ### [RQ2] Let's explore the dataset by finding simple insights into the reviews.

# %% [markdown]
# #### A) Plot the number of reviews for each application in descending order.

# %% [markdown]
# ### Because of the fact that i could not read all the the data from csv i just used language to show better plot instead of app_name

# %%
plt.barh(data["language"].value_counts().index[0:15], data["language"].value_counts().values[0:15])
plt.ticklabel_format(useOffset=False, style='plain', axis='x')
plt.gca().invert_yaxis()
plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
#  Bar plot
plt.bar(data["language"].value_counts().index[0:15], data["language"].value_counts().values[0:15], color ='green',
        width = 0.5)
plt.xticks(rotation='vertical')
plt.xlabel("language")
plt.ylabel("No. of reviews")
plt.title("No of reviews by language")
plt.show()

# %% [markdown]
# #### B) What applications have the best Weighted Vote Score?

# %%
best_score_app = data.groupby('language').weighted_vote_score.sum().round(2).sort_values(ascending= False)
best_score_app
# Out:
# language
# english       2222.07
# russian       2131.19
# schinese      1467.86
# turkish        981.09
# polish         496.22
# brazilian      486.78
# spanish        224.48
# german         148.86
# koreana        129.34
# french          78.32
# czech           71.46
# tchinese        51.81
# latam           41.59
# japanese        31.49
# ukrainian       28.40
# italian         26.38
# portuguese      20.92
# hungarian       17.57
# thai            16.80
# swedish          8.13
# finnish          7.86
# dutch            5.62
# greek            3.34
# danish           3.16
# norwegian        2.59
# vietnamese       2.07
# romanian         1.97
# bulgarian        0.53
# Name: weighted_vote_score, dtype: float64

# %% [markdown]
# #### c) Which applications have the most and the least recommendations?

# %%
print(data[data["recommended"]== True].groupby(['app_name']).recommended.sum().sort_values(ascending = False).head(10))
print(data[data["recommended"]== True].groupby(['app_name']).recommended.sum().sort_values(ascending = False).tail(10))
print(data[data["recommended"]== True].groupby(['language']).recommended.sum().sort_values(ascending = False).head(10))
print(data[data["recommended"]== True].groupby(['language']).recommended.sum().sort_values(ascending = False).tail(10))
# Out:
# app_name
# The Witcher 3: Wild Hunt    97678
# Name: recommended, dtype: int64
# app_name
# The Witcher 3: Wild Hunt    97678
# Name: recommended, dtype: int64
# language
# english      24279
# schinese     23332
# russian      17705
# turkish       7857
# brazilian     5950
# polish        5751
# spanish       2838
# german        2186
# koreana       1698
# french        1322
# Name: recommended, dtype: int64
# language
# swedish       195
# dutch         146
# finnish       112
# japanese       94
# greek          79
# danish         78
# vietnamese     77
# norwegian      68
# romanian       37
# bulgarian      10
# Name: recommended, dtype: int64

# %% [markdown]
# ### The most recommended language is english and the least bulgarian

# %% [markdown]
# #### d) How many of these applications were purchased, and how many were given for free?

# %%
print('for free',data[data["received_for_free"] == True].shape[0])
print('purchased',data.shape[0] - data[data["received_for_free"] == True].shape[0])
# Out:
# for free 1447
# purchased 98553

# %% [markdown]
# ## [RQ3] Now it's important to understand the preferred time to do reviews.

# %% [markdown]
# ### a) What is the most common time that authors review an application? For example, authors usually write a review at 17:44.

# %%
datetime = pd.to_datetime(data["timestamp_created"], unit='s')
max_=datetime.dt.time.value_counts()
print(max_.head(1))
# Out:
# 09:45:34    9
# Name: timestamp_created, dtype: int64

# %% [markdown]
# ### [RQ4] As Steam is a worldwide platform, the reviews can be done in many languages. Let's extract some information about it.

# %% [markdown]
# ### a) What are the top 3 languages used to review applications?

# %%
data.language.value_counts().head(3)
# Out:
# english     24956
# schinese    24110
# russian     17970
# Name: language, dtype: int64

# %% [markdown]
# ## [RQ5] Plot the top 10 most popular reviewers and the number of reviews:

# %% [markdown]
# ### [RQ5] a. Plot the top 10 most popular reviewers and the number of reviews.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'app_id', 'app_name', 'review_id', 'language', 'review',
#        'timestamp_created', 'timestamp_updated', 'recommended',
#        'votes_helpful', 'votes_funny', 'weighted_vote_score', 'comment_count',
#        'steam_purchase', 'received_for_free', 'written_during_early_access',
#        'author.steamid', 'author.num_games_owned', 'author.num_reviews',
#        'author.playtime_forever', 'author.playtime_last_two_weeks',
#        'author.playtime_at_review', 'author.last_played'],
#       dtype='object')

# %%
data.columns[-7]
# Out:
# 'author.steamid'

# %%
data["author.num_reviews"].max()
# max for the number of reviews
# Out:
# 2627

# %%
data[data["author.num_reviews"] == 2627]
# just to see which user has made the most reviews (2627)
# Out:
#        Unnamed: 0  app_id                  app_name  review_id language  \
# 46417       46417  292030  The Witcher 3: Wild Hunt   78305765  english
#
#                                                   review  timestamp_created  \
# 46417  Solid stand alone game, you dont need to play ...         1603916959
#
#        timestamp_updated  recommended  votes_helpful  ...  steam_purchase  \
# 46417         1605071148         True              4  ...           False
#
#        received_for_free  written_during_early_access     author.steamid  \
# 46417              False                        False  76561198094803808
#
#        author.num_games_owned  author.num_reviews  author.playtime_forever  \
# 46417                    2329                2627                  12170.0
#
#        author.playtime_last_two_weeks  author.playtime_at_review  \
# 46417                             0.0                    10416.0
#
#        author.last_played
# 46417        1.605646e+09
#
# ...

# %%
data["author.num_reviews"].sort_values(ascending=False)
# here I see that there are many duplicates
# Out:
# 46417    2627
# 60131    2378
# 7320     2063
# 78504    1915
# 3324     1162
#          ...
# 38244       1
# 77983       1
# 38248       1
# 38249       1
# 99999       1
# Name: author.num_reviews, Length: 100000, dtype: int64

# %%
data.nlargest(10, ["author.num_reviews"])
# same here, issue of duplicates
# Out:
#        Unnamed: 0  app_id                  app_name  review_id   language  \
# 46417       46417  292030  The Witcher 3: Wild Hunt   78305765    english
# 60131       60131  292030  The Witcher 3: Wild Hunt   75682403    english
# 7320         7320  292030  The Witcher 3: Wild Hunt   83988894    english
# 78504       78504  292030  The Witcher 3: Wild Hunt   72706950    russian
# 3324         3324  292030  The Witcher 3: Wild Hunt   84569639    russian
# 97950       97950  292030  The Witcher 3: Wild Hunt   70068852  brazilian
# 26141       26141  292030  The Witcher 3: Wild Hunt   81297143    english
# 25380       25380  292030  The Witcher 3: Wild Hunt   81387700  brazilian
# 69384       69384  292030  The Witcher 3: Wild Hunt   74321379    english
# 18241       18241  292030  The Witcher 3: Wild Hunt   82452682    english
#
#                                                   review  timestamp_created  \
# 46417  Solid stand alone game, you dont need to play ...         1603916959
# ...

# %%
df = data.nlargest(50, ["author.num_reviews"])
df
# Out:
#        Unnamed: 0  app_id                  app_name  review_id   language  \
# 46417       46417  292030  The Witcher 3: Wild Hunt   78305765    english
# 60131       60131  292030  The Witcher 3: Wild Hunt   75682403    english
# 7320         7320  292030  The Witcher 3: Wild Hunt   83988894    english
# 78504       78504  292030  The Witcher 3: Wild Hunt   72706950    russian
# 3324         3324  292030  The Witcher 3: Wild Hunt   84569639    russian
# 97950       97950  292030  The Witcher 3: Wild Hunt   70068852  brazilian
# 26141       26141  292030  The Witcher 3: Wild Hunt   81297143    english
# 25380       25380  292030  The Witcher 3: Wild Hunt   81387700  brazilian
# 69384       69384  292030  The Witcher 3: Wild Hunt   74321379    english
# 18241       18241  292030  The Witcher 3: Wild Hunt   82452682    english
# 41313       41313  292030  The Witcher 3: Wild Hunt   79189062  brazilian
# 67679       67679  292030  The Witcher 3: Wild Hunt   74697064    turkish
# ...

# %%
df = df[['author.steamid', 'author.num_reviews']]
df.head(15)
# Out:
#           author.steamid  author.num_reviews
# 46417  76561198094803808                2627
# 60131  76561198045381877                2378
# 7320   76561198202529859                2063
# 78504  76561198013146396                1915
# 3324   76561198027286434                1162
# 97950  76561198381331097                1124
# 26141  76561198016046767                1011
# 25380  76561198811822632                 829
# 69384  76561197994002775                 816
# 18241  76561197967685936                 683
# 41313  76561198308628242                 679
# 67679  76561198298095879                 674
# 54637  76561198854641697                 663
# 65320  76561198041885150                 609
# 46432  76561198117674830                 593

# %%
df = df.copy()

# %%
df.drop_duplicates(subset=['author.steamid'], keep='last', inplace= True)

# %%
df
# Out:
#           author.steamid  author.num_reviews
# 46417  76561198094803808                2627
# 60131  76561198045381877                2378
# 7320   76561198202529859                2063
# 78504  76561198013146396                1915
# 3324   76561198027286434                1162
# 97950  76561198381331097                1124
# 26141  76561198016046767                1011
# 25380  76561198811822632                 829
# 69384  76561197994002775                 816
# 18241  76561197967685936                 683
# 41313  76561198308628242                 679
# 67679  76561198298095879                 674
# 54637  76561198854641697                 663
# 65320  76561198041885150                 609
# 46432  76561198117674830                 593
# 66925  76561197992229015                 532
# 33709  76561198093298055                 531
# 54080  76561197969062133                 520
# 66671  76561198057386857                 512
# 25874  76561198997403008                 507
# ...

# %%
df = df.head(10)
df
# Out:
#           author.steamid  author.num_reviews
# 46417  76561198094803808                2627
# 60131  76561198045381877                2378
# 7320   76561198202529859                2063
# 78504  76561198013146396                1915
# 3324   76561198027286434                1162
# 97950  76561198381331097                1124
# 26141  76561198016046767                1011
# 25380  76561198811822632                 829
# 69384  76561197994002775                 816
# 18241  76561197967685936                 683

# %%
df.plot(x = "author.steamid", kind="bar", figsize = (13,7), title ="top 10 most popular reviewers",
       ylabel='Number of Reviews', xlabel = "Author Steam-id", grid = True, color= "r");

# %% [markdown]
# #### [RQ5] b. What applications did the most popular author review?

# %%
popular = data.groupby(['author.steamid']).size().sort_values().tail(1).index[0]
app_names = list(data[data["author.steamid"] == mostpopular].app_name.unique())
print(len(app_names), "app_names:")
for i in range (len(app_names)):
  print(app_names[i])
# Out:
# 1 app_names:
# The Witcher 3: Wild Hunt

# %% [markdown]
# ### [RQ7] a. What’s the probability that a review has a Weighted Vote Score equal to or bigger than 0.5?

# %%
pmorethan5 = (len(data.loc[data["weighted_vote_score"] >= 0.5] )/ len(data))
print(format(pmorethan5))
# Out:
# 0.1266

# %% [markdown]
# ##### it shows not right answer because of the lack of data but the way of sollving is true

# %% [markdown]
# ### [RQ7] b

# %%
wvs = data[data["weighted_vote_score"] > 0.5]
probwvs = wvs.shape[0]/data.shape[0]
intersect = data[(data["votes_funny"] >= 1) & (data["weighted_vote_score"] > 0.5)]
p = intersect.shape[0]/data.shape[0]
print(p/probwvs)
# Out:
# 0.13469584808496943

# %% [markdown]
# ### [RQ7] c

# %%
probAll = probwvs * data[data["weighted_vote_score"] > 0.5].shape[0]/data.shape[0]
print(probAll)
if (probAll == p):
  print("are indipendent")
else:
  print("are not dependent")
# Out:
# 0.0154455184
# are not dependent
